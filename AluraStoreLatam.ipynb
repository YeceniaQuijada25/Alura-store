# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ##Calificación promedio de la tienda 1

# %%
Promedio_Tienda1=tienda['Calificación'].mean()
print('La calificación promedio de la tienda 1 es: %f'%Promedio_Tienda1)
# Out:
# La calificación promedio de la tienda 1 es: 3.976685

# %% [markdown]
# ## Calificación promedio de la tienda 2

# %%
Promedio_Tienda2=tienda2['Calificación'].mean()
print('La calificación promedio de la tienda 2 es:%f'%Promedio_Tienda2)
# Out:
# La calificación promedio de la tienda 2 es:4.037304

# %% [markdown]
# ## Califcación promedio de la tienda 3

# %%
Promedio_Tienda3=tienda3['Calificación'].mean()
print('La calificación promedio de la tienda 3 es. %f'%Promedio_Tienda3)
# Out:
# La calificación promedio de la tienda 3 es. 4.048326

# %% [markdown]
# ##Calificación promedio de la tienda 4

# %%
Promedio_Tienda4=tienda4['Calificación'].mean()
print('La calificación promedio de la tienda 4 es:%f'%Promedio_Tienda4)
# Out:
# La calificación promedio de la tienda 4 es:3.995759

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ##Tienda 1

# %%
Envio_Promedio1=tienda['Costo de envío'].mean()
print('Él envío promedio de la tienda 1 es: %f'%Envio_Promedio1)
# Out:
# Él envío promedio de la tienda 1 es: 26018.609580

# %% [markdown]
# ## Tienda 2

# %%
Envio_Promedio2=tienda2['Costo de envío'].mean()
print('El envío promedio de la tienda 2 es:%f'%Envio_Promedio2)
# Out:
# El envío promedio de la tienda 2 es:25216.235693

# %% [markdown]
# ##Tienda 3

# %%
Envío_Promedio3=tienda3['Costo de envío'].mean()
print('El envío promedio de la tienda 3 es: %f'%Envío_Promedio3)
# Out:
# El envío promedio de la tienda 3 es: 24805.680373

# %% [markdown]
# ##Tienda 4

# %%
Envío_Promedio4=tienda4['Costo de envío'].mean()
print('El envío promedio de la tienda 4 es: %f'%Envío_Promedio4)
# Out:
# El envío promedio de la tienda 4 es: 23459.457167
